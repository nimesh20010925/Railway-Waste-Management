# %%
# !nvidia-smi
# Out:
# Tue Nov 11 12:14:03 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   67C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 35.5 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
# "2023-04-07 21.40.14 nimesh perera's Personal Meeting Room"
# 'application for fcsc.pdf'
#  asinment
#  BMIT
#  BOCDownload_22_11_202220_24_35.pdf
# 'Colab Notebooks'
# 'c programin'
# 'c programming and pdf'
# 'c programming and pdf.rar'
# 'c programming kuppiya.rar'
# 'c programming tutorial'
#  custom_model_train_test
# 'cv application for fcsc.pdf'
#  cv.pdf
#  face_detection
# 'Form I-6(IT22582324Sendanayaka H.K.)IT.docx'
#  HCI
#  himasha
# 'himasha work break down .drawio'
# 'himasha work breakdown.drawio'
# 'html basic'
#  IMG_20230228_182316.jpg
# 'ISDM VIVA'
# 'ITPM Reserch'
#  IWT
# 'mac folder'
# 'MSAN WEB APP'
# 'my protfolio site contact.gsheet'
# 'New folder'
#  newvideo.mp4
#  NHR-Insurance
#  Nimesh_Perera.pdf
# "Organizations' Responsibilities and TasksUntitled document.gdoc"
#  pactricle
#  project1
#  realistic_synthetic_health_dataset.csv.csv
# 'RP Budget'
# 'Screenshot_20240306_105929_com (1).huawei.email.jpg'
#  Screenshot_20240306_105929_com.huawei.email.jpg
# ...

# %%
# %cd "/content/drive/MyDrive/waste and non waste detection.v1i.yolov8"
# Out:
# /content/drive/MyDrive/waste and non waste detection.v1i.yolov8

# %%
# !ls
# Out:
#  data.yaml	      README.roboflow.txt   train  'weste detection.ipynb'
#  README.dataset.txt   test		    valid

# %%
# !ls -R
# Out:
# .:
#  data.yaml	      README.roboflow.txt   train  'weste detection.ipynb'
#  README.dataset.txt   test		    valid
#
# ./test:
# images	labels
#
# ./test/images:
# image_107_jpg.rf.08e955f2243328e8402f42fa3406fd7b.jpg
# image_108_jpg.rf.b087a056ceb0495ed35eaeca53e1b032.jpg
# image_11_jpg.rf.1ac357881c738c77c10482cce54a37b9.jpg
# image_125_jpeg.rf.c8f767beed9330eb01b29a627bf57dfe.jpg
# image_12_jpg.rf.fd89d6d914d1d01a25bd7c2c8ac863c0.jpg
# image_159_jpeg.rf.4a96aea41e651a00156b61c0491d9334.jpg
# image_160_jpeg.rf.7488c8f3fe7d692c58662deb5fba9209.jpg
# image_161_jpeg.rf.11b79217d2f3b2304c123d955f0ce49e.jpg
# image_164_jpeg.rf.16f64b22dbab385a748fe3c360971228.jpg
# image_167_jpeg.rf.125d5bdb659e6ea35a1b6b820d873a5b.jpg
# image_169_jpeg.rf.152dba89686cf19fe533e4be7e4c7e76.jpg
# image_170_jpeg.rf.f5c77d8e57f29f627ddd05fcfab81e69.jpg
# image_177_jpeg.rf.25087f6baef7e506bf8e55e61682ac3e.jpg
# image_17_jpg.rf.c3c82e2a92836f6b947a418791a6d5f8.jpg
# ...

# %%
model = YOLO('yolov8n.pt')

# %%
model.train(
    data='data.yaml',       # path to your yaml file
    epochs=100,              # you can increase if needed
    imgsz=640,              # image size
    batch=16,               # batch size
    name='waste_yolov8',    # experiment name
)
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.227 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.5±0.2 ms, read: 9.3±5.0 MB/s, size: 22.6 KB)
# val: Scanning /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/valid/labels.cache... 104 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 104/104 115.6Kit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 7/7 2.4it/s 2.9s
#                    all        104        111          1      0.961      0.993       0.84
# Speed: 6.7ms preprocess, 5.5ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/runs/detect/val
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.utils.metrics.Metric object
# ...

# %%
results = model.predict(
    source='test/images',  # path to your test folder
    save=True              # saves output images with predictions
)
# Out:
# image 1/52 /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/test/images/image_107_jpg.rf.08e955f2243328e8402f42fa3406fd7b.jpg: 640x640 1 waste, 7.4ms
# image 2/52 /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/test/images/image_108_jpg.rf.b087a056ceb0495ed35eaeca53e1b032.jpg: 640x640 1 waste, 7.3ms
# image 3/52 /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/test/images/image_11_jpg.rf.1ac357881c738c77c10482cce54a37b9.jpg: 640x640 1 waste, 7.3ms
# image 4/52 /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/test/images/image_125_jpeg.rf.c8f767beed9330eb01b29a627bf57dfe.jpg: 640x640 1 waste, 7.4ms
# image 5/52 /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/test/images/image_12_jpg.rf.fd89d6d914d1d01a25bd7c2c8ac863c0.jpg: 640x640 1 waste, 7.3ms
# ...

# %%
# !ls runs/detect/waste_yolov8/weights/

# %%
# !ls runs/detect/waste_yolov8/weights/

# %%
from google.colab import files

# %%
# !find /content -type f -name "best.pt"
# Out:
# /content/drive/MyDrive/waste and non waste detection.v1i.yolov8/runs/detect/waste_yolov82/weights/best.pt

# %%
from google.colab import files
files.download("/content/drive/MyDrive/waste and non waste detection.v1i.yolov8/runs/detect/waste_yolov82/weights/best.pt")
